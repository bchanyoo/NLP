# %% [markdown]
# <a href="https://colab.research.google.com/github/bchanyoo/NLP/blob/main/NLP%20Wikidocs_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
train_text = 'The earth is an awesome place live'

#단어 집합 생성
#fit_on_texts 메서드를 호출하면 텍스트 데이터 내의 단어들을 토크나이징하고
#각 단어에 고유한 정수를 할당하여 단어 집합을 구성함.
tokenizer.fit_on_texts([train_text])

#정수 인코딩
sub_text = 'The earth is an great place live'
sequences = tokenizer.texts_to_sequences([sub_text])[0]

print('정수 인코딩', sequences)
print('단어 집합', tokenizer.word_index)
# Out:
# 정수 인코딩 [1, 2, 3, 4, 6, 7]
# 단어 집합 {'the': 1, 'earth': 2, 'is': 3, 'an': 4, 'awesome': 5, 'place': 6, 'live': 7}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sequences = pad_sequences([[1,2,3],[3,4,5,6],[7,8]], maxlen = 3, padding = 'pre')
sequences
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [0, 7, 8]], dtype=int32)

# %% [markdown]
# ### Word Embedding
#
# ![image.png](data:image/png;base64,...)

# %%
# 수도코드임.

# 1. 토큰화
tokenized_text = [['Hope', 'to', 'see', 'you', 'soon'], ['Nice', 'to', 'see', 'you', 'again']]

# 2. 각 단어에 대한 정수 인코딩
encoded_text = [[0, 1, 2, 3, 4],[5, 1, 2, 3, 6]]

# 3. 위 정수 인코딩 데이터가 아래의 임베딩 층의 입력이 된다.
vocab_size = 7
embedding_dim = 2
#Embedding(vocab_size, embedding_dim, input_length=5)

# 각 정수는 아래의 테이블의 인덱스로 사용되며 Embedding()은 각 단어마다 임베딩 벡터를 리턴한다.
#+------------+------------+
#|   index    | embedding  |
#+------------+------------+
#|     0      | [1.2, 3.1] |
#|     1      | [0.1, 4.2] |
#|     2      | [1.0, 3.1] |
#|     3      | [0.3, 2.1] |
#|     4      | [2.2, 1.4] |
#|     5      | [0.7, 1.7] |
#|     6      | [4.1, 2.0] |
#+------------+------------+

# 위의 표는 임베딩 벡터가 된 결과를 예로서 정리한 것이고 Embedding()의 출력인 3D 텐서를 보여주는 것이 아님.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Modeling
# Sequential 사용하기.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#아래는 model.add()로 층을 추가하는 예제 코드임.
#실제로는 온점 대신 층 이름 기재해야 함.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = Sequential()
model.add(Dense(8, input_dim = 4, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid')) #출력층

#하단은 시각화

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.layers import SimpleRNN, Embedding, Dense
from tensorflow.keras.models import Sequential

# %%
vocab_size = 10000
embedding_dim = 32
hidden_units = 32

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(SimpleRNN(hidden_units))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy', metrics = ['acc'])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
